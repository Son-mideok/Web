# %% [markdown]
# <a href="https://colab.research.google.com/github/Son-mideok/e-Learning/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_%EB%82%98%EB%93%A4%EC%9D%B4_%EA%B3%B5%EC%9B%90%EC%A7%80%EB%8F%84_%EC%88%98%EC%A0%95%EC%A4%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 한글폰트 설정 및 라이브러리 임포트

# %%
# 코드 실행 후 재시작
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %% [markdown]
# # 필요한 라이브러리 import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 멧플롯립 한글폰트 지정
plt.rc('font', family='NanumBarunGothic')    # 코랩에서 사용
# plt.rc('font', family='Malgun Gothic')    # 윈도우에서 사용
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 나들이 공원지도
#  - 서울시 공원 위치 정보를 제공하는 지도 시각화

# %% [markdown]
# ## 파일 읽어서 데이터프레임 생성하기

# %%
import pandas as pd
df = pd.read_csv('서울시 주요 공원현황.csv', encoding='cp949')
df.head()
# Out:
#    연번       공원명                                               공원개요  \
# 0   1  남산도시자연공원  남산공원은 도심에 위치하여 서울시민에게 맑은 공기를 제공하는 자연휴식처이며 산책 꽃...
# 1   2    길동생태공원  길동생태공원은 생물의 서식처를 제공하고 종다양성을 증진시키며 자연생태계의 생물들을 ...
# 2   3     서울대공원  서울대공원은 세계 각국의 야생동물들이 살아 숨 쉬는 서울동물원과 다양한 재미와 즐거...
# 3   4       서울숲  당초 골프장 승마장 등이 있던 뚝섬일대를 주거업무 지역으로 개발할 경우 약 4조원에...
# 4   5     월드컵공원  월드컵공원은 서울의 서쪽에 위치하여 1978년부터 1993년까지 15년간 서울시민이...
#
#                                              면적        개원일  \
# 0  2896887㎡ 임 야 : 2454140㎡ 녹지대 및 기타시설 : 442747㎡  1968.9.10
# 1                                        80683㎡  1999.5.20
# 2                                     9132690m²   1984.5.1
# 3                                       480994㎡  2005.6.18
# 4                                      2284085㎡   2002.5.1
#
#                                                 주요시설  \
# 0  기반시설 : 광장 45950㎡ 도로 108530㎡ 산책로 6.7㎞ (북측:3.7㎞/...
# 1               탐방객안내소 야외전시대 관찰대 목재데크 조류관찰대 길동생태문화센터
# ...

# %% [markdown]
# ## 데이터 구조 탐색하기

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   연번            132 non-null    int64
#  1   공원명           132 non-null    object
#  2   공원개요          131 non-null    object
#  3   면적            129 non-null    object
#  4   개원일           122 non-null    object
#  5   주요시설          124 non-null    object
#  6   주요식물          88 non-null     object
#  7   안내도           102 non-null    object
#  8   오시는길          115 non-null    object
#  9   이용시참고사항       120 non-null    object
#  10  이미지           132 non-null    object
#  11  지역            131 non-null    object
#  12  공원주소          132 non-null    object
#  13  관리부서          132 non-null    object
#  14  전화번호          132 non-null    object
#  15  X좌표(GRS80TM)  122 non-null    float64
#  16  Y좌표(GRS80TM)  122 non-null    float64
#  17  X좌표(WGS84)    131 non-null    float64
# ...

# %%
# 결측치 확인
df[ df['공원주소'].isnull() ]
# Out:
# Empty DataFrame
# Columns: [연번, 공원명, 공원개요, 면적, 개원일, 주요시설, 주요식물, 안내도, 오시는길, 이용시참고사항, 이미지, 지역, 공원주소, 관리부서, 전화번호, X좌표(GRS80TM), Y좌표(GRS80TM), X좌표(WGS84), Y좌표(WGS84), 바로가기]
# Index: []

# %%
#'공원명'컬럼의 데이터 확인하기
df['공원명'].value_counts()
# Out:
# 공원명
# 남산도시자연공원      1
# 수락산도시자연공원     1
# 발바닥공원         1
# 만수천공원(관악산)    1
# 금천폭포근린공원      1
#              ..
# 노량진공원         1
# 꿩고개근린공원       1
# 까치산근린공원       1
# 궁산근린공원        1
# 서울로7017       1
# Name: count, Length: 132, dtype: int64

# %%
# 결측치 데이터 확인하기
# df.isnull()
df.isnull().sum()
# Out:
# 연번                0
# 공원명               0
# 공원개요              1
# 면적                3
# 개원일              10
# 주요시설              8
# 주요식물             44
# 안내도              30
# 오시는길             17
# 이용시참고사항          12
# 이미지               0
# 지역                1
# 공원주소              0
# 관리부서              0
# 전화번호              0
# X좌표(GRS80TM)     10
# Y좌표(GRS80TM)     10
# X좌표(WGS84)        1
# Y좌표(WGS84)        1
# 바로가기            114
# dtype: int64

# %%
# 특정 컬럼의 결측치 확인
df[df['공원개요'].isnull()]
# df.loc[df['소재지(도로명)'].isnull()]
# Out:
#       연번        공원명 공원개요        면적  개원일 주요시설 주요식물  \
# 114  115  인능산도시자연공원  NaN  2400833㎡  NaN  NaN  NaN
#
#                                                    안내도  \
# 114  http://parks.seoul.go.kr/upload/seditorMulti/2...
#
#                                                   오시는길  \
# 114  버스 : 양재역 중앙버스정류장에서 440 462 407 408 140번 버스 탑승 ...
#
#                                                이용시참고사항  \
# 114  코스설명  - 1코스 : 서울특별시립 어린이병원 → 내곡보금자리 뒤(홍씨마을) → ...
#
#                                                    이미지   지역  \
# 114  http://parks.seoul.go.kr/file/info/view.do?fId...  서초구
#
#                       공원주소         관리부서          전화번호  X좌표(GRS80TM)  \
# 114  서울특별시 서초구 내곡동 산12-404  서초구청 푸른산관리팀  02-2155-6873   205898.0861
#
#      Y좌표(GRS80TM)  X좌표(WGS84)  Y좌표(WGS84) 바로가기
# 114   438764.8767  127.066663   37.448211  NaN

# %%
# 특정 컬럼의 결측치 확인
df[df['주요시설'].isnull()]
# df.loc[df['소재지(도로명)'].isnull()]
# Out:
#       연번        공원명                                               공원개요  \
# 13    14    간데메근린공원  옛날 답십리 일대에 원말(원촌) 넘말(월촌) 간데메(중산)의 마을이 흩어져 있었는데...
# 68    69    북한산국립공원  북한산 도시자연공원은 크게 2개 지역으로 나누어져 있는데 은평구 녹번동과 서대문구 ...
# 109  110      푸른수목원  서울의 서남쪽 구로구의 끝자락에 위치한 푸른수목원은 서울시 최초로 조성되는 시립수목...
# 114  115  인능산도시자연공원                                                NaN
# 115  116        구룡산  구룡산은 대모산과 하나의 줄기를 가진 산으로 서초구와 강남구 경계에 걸쳐 있으며 두...
# 119  120  문화역 서울284  누구에게나 열려있는 역동적이고 개방된 복합문화공간입니다. 대한민국 근현대사의 주요무...
# 125  126     숭인근린공원  서울특별시 종로구 숭인동 동망산(東望山)에 있는 공원이다. 동망산공원이라고도 한다....
# 131  132    서울로7017  서울로7017은 70년대 준공된 서울역 고가가 안전에 문제점이 도출되면서 철거가 될...
#
#              면적         개원일 주요시설                      주요식물  \
# 13   15179.7 ㎡          NaN  NaN                       NaN
# 68     1667848㎡    1983.4.2  NaN  수 목 : 소나무단풍나무  초 화 : 장미
# 109         NaN         NaN  NaN                       NaN
# 114    2400833㎡         NaN  NaN                       NaN
# ...

# %% [markdown]
# ## 데이터 전처리하기

# %%
df['X좌표(WGS84)']
# Out:
# 0      126.990377
# 1      127.154779
# 2      127.019846
# 3      127.041798
# 4      126.878907
#           ...
# 127    127.095997
# 128    126.893246
# 129    127.076482
# 130    127.115594
# 131           NaN
# Name: X좌표(WGS84), Length: 132, dtype: float64

# %%
df['Y좌표(WGS84)']
# Out:
# 0      37.550140
# 1      37.540394
# 2      37.426449
# 3      37.543072
# 4      37.571805
#          ...
# 127    37.579762
# 128    37.571718
# 129    37.627077
# 130    37.472332
# 131          NaN
# Name: Y좌표(WGS84), Length: 132, dtype: float64

# %% [markdown]
# ### 이상치 확인하기
# - 수치형 값을 갖는 'X축', 'Y축' 컬럼에 이상치가 있는지 boxplot으로 확인

# %%
# 위도: Y좌표(WGS84)
# 경도: X좌표(WGS84)

import matplotlib.pyplot as plt

ax1 = plt.subplot(121) # (1) 첫 번째 공간에 axes 생성
ax1.boxplot(df['Y좌표(WGS84)'])
ax2 = plt.subplot(122)
ax2.boxplot(df['X좌표(WGS84)'])
plt.show()

# %% [markdown]
# ### 불필요한 컬럼 삭제하기
# - 지도에 표시할 위도& 경도는 'X좌표(WGS84)', 'Y좌표(WGS84)' 컬럼을 사용하므로 'X좌표(GRS80TM)', 'Y좌표(GRS80TM)' 컬럼은 삭제한다.
# - '연번', '면적', '개원일', '주요식물', '안내도', '오시는길', '이미지','관리부서','전화번호', '바로가기' 컬럼도 분석에 필요하지 않은 내용으로 보고 삭제한다.

# %%
# df.drop(columns=['면적', '개원일', '주요식물', '안내도', '오시는길', '이미지', '관리부서', '전화번호', '바로가기', 'X좌표(GRS80TM)', 'Y좌표(GRS80TM)'], axis=1, inplace=True)
df.drop(columns=['연번'], axis=1, inplace=True)  # 누락한 추가 컬럼 삭제
df.isnull().sum()
# Out:
# 공원명            0
# 공원개요           1
# 주요시설           8
# 이용시참고사항       12
# 지역             1
# 공원주소           0
# X좌표(WGS84)     1
# Y좌표(WGS84)     1
# dtype: int64

# %%
df.head()
# Out:
#         공원명                                               공원개요  \
# 0  남산도시자연공원  남산공원은 도심에 위치하여 서울시민에게 맑은 공기를 제공하는 자연휴식처이며 산책 꽃...
# 1    길동생태공원  길동생태공원은 생물의 서식처를 제공하고 종다양성을 증진시키며 자연생태계의 생물들을 ...
# 2     서울대공원  서울대공원은 세계 각국의 야생동물들이 살아 숨 쉬는 서울동물원과 다양한 재미와 즐거...
# 3       서울숲  당초 골프장 승마장 등이 있던 뚝섬일대를 주거업무 지역으로 개발할 경우 약 4조원에...
# 4     월드컵공원  월드컵공원은 서울의 서쪽에 위치하여 1978년부터 1993년까지 15년간 서울시민이...
#
#                                                 주요시설  \
# 0  기반시설 : 광장 45950㎡ 도로 108530㎡ 산책로 6.7㎞ (북측:3.7㎞/...
# 1               탐방객안내소 야외전시대 관찰대 목재데크 조류관찰대 길동생태문화센터
# 2  동물원 식물원 테마가든(장미원 어린이동물원 피크닉장) 치유숲 산림욕장 캠핑장 국립현...
# 3  4개 테마공원: 문화예술공원 자연생태숲 자연체험학습원 습지생태원 주요시설: 가족마당...
# 4  평화의 공원 월드컵공원전시관(879㎡) 유니세프광장(2400㎡) 평화광장(5217㎡...
#
#                                              이용시참고사항   지역  \
# 0  남산공원 차량통행 금지안내 2005년 5월 1일부터 남산공원에 일반승용차 택시 통행...   중구
# 1  매주 월요일은 휴관입니다 사전예약 후 입장하실 수 있습니다. ▶ 인터넷 예약 바로가...  강동구
# 2  일반사항 공원을 깨끗하게 이용합니다. 대중교통을 이용해 주세요. 기념물 시설물 풀과...  과천시
# ...

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```
#
# ###  공원주소에서 시, 도, 구 정보 추출하기
# - 도로명 주소이기때문에 의도대로 추출할 수 없어 다른 방안 고민

# %%
df['공원주소'].str.split(' ').str[2]
# Out:
# 0        삼일대로
# 1        천호대로
# 2      대공원광장로
# 3         뚝섬로
# 4       하늘공원로
#         ...
# 127      면목7동
# 128       증산로
# 129         산
# 130       율현동
# 131       NaN
# Name: 공원주소, Length: 132, dtype: object

# %%
df['지역'].head()
# Out:
# 0     중구
# 1    강동구
# 2    과천시
# 3    성동구
# 4    마포구
# Name: 지역, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   공원명         132 non-null    object
#  1   공원개요        131 non-null    object
#  2   주요시설        124 non-null    object
#  3   이용시참고사항     120 non-null    object
#  4   지역          131 non-null    object
#  5   공원주소        132 non-null    object
#  6   X좌표(WGS84)  131 non-null    float64
#  7   Y좌표(WGS84)  131 non-null    float64
# dtypes: float64(2), object(6)
# memory usage: 8.4+ KB

# %% [markdown]
# ## 데이터 탐색하기

# %% [markdown]
# ### 공원이 제일 많은 동네는 어디일까?

# %%
df['지역'].value_counts()
# Out:
# 지역
# 종로구     12
# 강서구      9
# 동작구      7
# 강남구      7
# 은평구      7
# 강동구      7
# 송파구      7
# 중랑구      6
# 서초구      6
# 도봉구      6
# 중구       5
# 영등포구     5
# 마포구      5
# 성동구      5
# 양천구      5
# 강북구      4
# 구로구      4
# 서대문구     4
# 금천구      4
# 동대문구     4
# 성북구      3
# 관악구      2
# 용산구      2
# 광진구      2
# 노원구      2
# 과천시      1
# Name: count, dtype: int64

# %%
# 종로구-> 강서구 -> 동작구 순서로 공원이 많다.

# %%
# df.loc[]은 DataFrame에서 특정 행(row) 또는 열(column)을 선택하기 위해 사용되는 인덱싱 방법 중 하나입니다. 특정 행이나 열을 선택하거나 슬라이싱을 할 때 사용됩니다.

df.loc[df['지역']=='종로구'][['공원명', '공원주소']]
# Out:
#            공원명                           공원주소
# 5    광화문시민열린마당             서울특별시 종로구 세종로 76-2
# 21      낙산근린공원     서울특별시 종로구 낙산길 41 (우) 03085
# 28         경희궁   서울특별시 종로구 새문안로 55(신문로2가 2-1)
# 41      탑골근린공원                서울특별시 종로구 종로 99
# 49      마로니에공원              서울특별시 종로구 대학로8길 1
# 65      와룡근린공원  서울특별시 종로구 와룡공원길 192 (우) 03063
# 67   북악산도시자연공원             서울특별시 종로구 부암동 산2-6
# 75      사직근린공원              서울특별시 종로구 사직로9길 5
# 78      삼청근린공원  서울특별시 종로구 북촌로 134-1 (우) 03050
# 79   인왕산도시자연공원           서울특별시 종로구 옥인동 산 3-1
# 106      세종로공원   서울특별시 종로구 세종대로 189 (우) 03172
# 125     숭인근린공원               서울특별시 종로구 숭인동 58

# %% [markdown]
# ### 강서구/구로구에 있는 빵집의 주소 알아보기

# %%
# df.loc[df['지역']=='구로구'][['공원명', '공원주소']]
df.loc[df['지역']=='강서구'][['공원명', '공원주소']]
# Out:
#          공원명                      공원주소
# 9     매화근린공원      서울특별시 강서구 등촌동 630-14
# 33      허준공원        서울특별시 강서구 허준로5길 42
# 35    궁산근린공원        서울특별시 강서구 가양동 산4-7
# 37   꿩고개근린공원        서울특별시 강서구 방화동 산110
# 53    방화근린공원  서울특별시 강서구 금낭화로 176(방화공원)
# 57    염창근린공원       서울특별시 강서구 염창동 산24-1
# 76   우장산근린공원       서울특별시 강서구 내발산동 산4-5
# 88     봉제산공원       서울특별시 강서구 화곡동 산41-6
# 112   개화근린공원         서울특별시 강서구 개화동 산17

# %% [markdown]
# ## 데이터 시각화 하기
# - 지도위에 위치와 정보 표시하기
# - folium 사용법 <br>
# https://python-visualization.github.io/folium/quickstart.html#Getting-Started

# %% [markdown]
# ### folium사용하기

# %%
# !pip install folium

# %%
import folium

# %%
folium.__version__
# Out:
# '0.14.0'

# %%
# 초기위치(위도,경도)=강서여성인력개발센터 37.549328, 126.8513969
lati, long  = 37.549328, 126.8513969
map = folium.Map(location = [lati, long], zoom_start= 11)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map = folium.Map(location = [ lati, long ],
                 zoom_start= 12
                 )
tooltip = 'click'
folium.Marker(
    location = [lati, long ],
    popup = '<strong>hello jeju</strong>',
    icon = folium.Icon(color = 'pink', icon = 'heart'),
    tooltip = tooltip
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### 공원 위치 마커 표시하기

# %%
df.head()
# Out:
#         공원명                                               공원개요  \
# 0  남산도시자연공원  남산공원은 도심에 위치하여 서울시민에게 맑은 공기를 제공하는 자연휴식처이며 산책 꽃...
# 1    길동생태공원  길동생태공원은 생물의 서식처를 제공하고 종다양성을 증진시키며 자연생태계의 생물들을 ...
# 2     서울대공원  서울대공원은 세계 각국의 야생동물들이 살아 숨 쉬는 서울동물원과 다양한 재미와 즐거...
# 3       서울숲  당초 골프장 승마장 등이 있던 뚝섬일대를 주거업무 지역으로 개발할 경우 약 4조원에...
# 4     월드컵공원  월드컵공원은 서울의 서쪽에 위치하여 1978년부터 1993년까지 15년간 서울시민이...
#
#                                                 주요시설  \
# 0  기반시설 : 광장 45950㎡ 도로 108530㎡ 산책로 6.7㎞ (북측:3.7㎞/...
# 1               탐방객안내소 야외전시대 관찰대 목재데크 조류관찰대 길동생태문화센터
# 2  동물원 식물원 테마가든(장미원 어린이동물원 피크닉장) 치유숲 산림욕장 캠핑장 국립현...
# 3  4개 테마공원: 문화예술공원 자연생태숲 자연체험학습원 습지생태원 주요시설: 가족마당...
# 4  평화의 공원 월드컵공원전시관(879㎡) 유니세프광장(2400㎡) 평화광장(5217㎡...
#
#                                              이용시참고사항   지역  \
# 0  남산공원 차량통행 금지안내 2005년 5월 1일부터 남산공원에 일반승용차 택시 통행...   중구
# 1  매주 월요일은 휴관입니다 사전예약 후 입장하실 수 있습니다. ▶ 인터넷 예약 바로가...  강동구
# 2  일반사항 공원을 깨끗하게 이용합니다. 대중교통을 이용해 주세요. 기념물 시설물 풀과...  과천시
# ...

# %%
df.loc[0,'위도']
df.loc[5, '위도']
# Out:
# 33.22141736

# %% [markdown]
# ### 마커에 정보 넣기

# %%
for idx in df.index :
  lat = df.loc[idx,'위도']
  lng = df.loc[idx,'경도']
  marker = folium.Marker(
      location = [lat, lng],
      popup = f"<div style='width:100px'> <strong>{df.loc[idx,'업소명']}</strong><br>\
      {df.loc[idx, '소재지(지번)']}</div>",
      icon = folium.Icon(color='orange', icon='cloud')
      )
  marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 데이터 정렬()
df = df.sort_values(by=['읍면동','업소명'], ascending=True)

# 읍면동별로 아이콘 컬러를 다르게 설정하기
# help(folium.Icon)
colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']
v_idx = 0
v_color = 'orange'
v_읍면동 = df.loc[v_idx, '읍면동']
for idx in df.index :
    # 아이콘 색상 다르게 지정(읍면동별로)
    if df.loc[idx, '읍면동'] == v_읍면동:
        v_color = colors[v_idx]
    else:
        # 컬러의 새
        if len(colors)-1 == v_idx:
            v_idx = 0
        else:
            v_idx += 1
        v_color = colors[v_idx]
        v_읍면동 = df.loc[idx, '읍면동']
    lat = df.loc[idx,'위도']
    lng = df.loc[idx,'경도']
    marker = folium.Marker(
        location = [lat, lng],
        popup = f"<div style='width:100px'> <strong>{df.loc[idx,'업소명']}</strong><br>\
        {df.loc[idx, '소재지(지번)']}</div>",
        icon = folium.Icon(color=v_color, icon='cloud')
        )
    marker.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium.plugins import MarkerCluster

map = folium.Map(location = [33.3616666,126.5291666 ],
                 zoom_start= 10
                 )

marker_cluster = MarkerCluster().add_to(map)

for idx in df.index :
  lat = df.loc[idx,'위도']
  lng = df.loc[idx,'경도']
  marker = folium.Marker(
      location = [lat, lng],
      popup = f"<div style='width:100px'> <strong>{df.loc[idx,'업소명']}</strong><br>\
      {df.loc[idx, '소재지(지번)']}</div>",
      icon = folium.Icon(color='orange', icon='cloud')
      )
  marker.add_to(marker_cluster)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
